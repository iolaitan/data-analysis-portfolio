# %% [markdown]
# ### Webscraping - Properties on Zoopla

# %% [markdown]
# Search criteria:
# - For Sale
# - Max price: £300,000
# - Area: Liverpool
# - Type: House

# %% [markdown]
# Import the requests library which will make a 'GET' request to the web server and downloads the HTML contents of the webpage being scraped (https://www.zoopla.co.uk/).

# %%
import requests

# %% [markdown]
# Download the page using the requests.get method

# %%
page = requests.get("https://www.zoopla.co.uk/for-sale/houses/liverpool/?beds_max=2&price_max=300000&view_type=list&q=Liverpool%2C%20Merseyside&results_sort=newest_listings&search_source=home")
page
# Out:
# <Response [200]>

# %% [markdown]
# Check if the page was downloaded sucessfully

# %%
page.status_code
# Out:
# 200

# %% [markdown]
# >A status code starting a 2 = success, whereas a status code starting with 4 or 5 = an error

# %% [markdown]
# Use the BeautifulSoup library to parse the HTML document above and view page contents. The prettify function formats the page contents better.

# %%
from bs4 import BeautifulSoup
results = BeautifulSoup(page.content, "html.parser")
print(results.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB">
#  <head>
#   <script data-testid="inline-script">
#    !function(t){var e={};function n(r){if(e[r])return e[r].exports;var a=e[r]={i:r,l:!1,exports:{}};return t[r].call(a.exports,a,a.exports,n),a.l=!0,a.exports}n.m=t,n.c=e,n.d=function(t,e,r){n.o(t,e)||Object.defineProperty(t,e,{enumerable:!0,get:r})},n.r=function(t){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},n.t=function(t,e){if(1&e&&(t=n(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var r=Object.create(null);if(n.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var a in t)n.d(r,a,function(e){return t[e]}.bind(null,a));return r},n.n=function(t){var e=t&&t.__esModule?function(){return t.default}:function(){return t};return n.d(e,"a",e),e},n.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},n.p="https://gdpr.privacymanager.io/1.3.0/",n(n.s=2)}({2:function(t,e){!function(){if("function"!=typeof window.__tcfapi||window.__tcfapi&&"function"!=typeof window.__tcfapi.start){var t,e=[],n=window,r=n.document,a=n.__tcfapi?n.__tcfapi.start:function(){};if(!n.__tcfapi&&function t(){var e=!!n.frames.__tcfapiLocator;if(!e)if(r.body){var a=r.createElement("iframe");a.style.cssText="display:none",a.name="__tcfapiLocator",r.body.appendChild(a)}else setTimeout(t,5);return!e}()||n.__tcfapi&&!n.__tcfapi.start){var i=n.__tcfapi?n.__tcfapi():[];e.push.apply(e,i),n.__tcfapi=function(n,r,a,i){var o=[n,r,a,i];if(!o.length)return e;if("setGdprApplies"===o[0])o.length>3&&2===parseInt(o[1],10)&&"boolean"==typeof o[3]&&(t=o[3],"function"==typeof o[2]&&o[2]("set",!0));else if("ping"===o[0]){var f={gdprApplies:t,cmpLoaded:!1,apiVersion:"2.0"};"function"==typeof o[2]&&o[2](f,!0)}else e.push(o)},n.__tcfapi.commandQueue=e,n.__tcfapi.start=a,n.addEventListener("message",(function(t){var e="string"==typeof t.data,r={};try{r=e?JSON.parse(t.data):t.data}catch(t){}var a=r.__tcfapiCall;a&&n.__tcfapi(a.command,a.version,(function(n,r){if(t.source){var i={__tcfapiReturn:{returnValue:n,success:r,callId:a.callId,command:a.command}};e&&(i=JSON.stringify(i)),t.source.postMessage(i,"*")}}),a.parameter)}),!1)}}}()}});
#   </script>
#   <script type="text/javascript">
#    ;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true}};
# ;
#     window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(29),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(30),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),S=t(7),N=t(14),M=t(9),P=t("ee"),T=P.get("tracer");t(16),y.features.spa=!0;var C,L=0;P.on(u,r),b.on(p,r),M.on(p,r),P.on(d,o),b.on(l,o),M.on(l,o),P.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),N.buffer([u,"new-xhr","send-xhr"+s]),S.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),T.buffer([u,"no-"+u]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(N,"send-xhr"+s),a(P,"xhr-resolved"),a(P,"xhr-done"),a(S,m+s),a(S,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");if(!y.disabled){y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),s.on(m,function(){this.bstStart=y.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),o.on(g+l,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),o.on(g+h,function(t){i("bstHist",[l ...
#
# ;NREUM.loader_config={accountID:"2902499",trustKey:"2902499",agentID:"95776729",licenseKey:"NRJS-87cb4c448aca56623be",applicationID:"95776729"}
# ;NREUM.info={beacon:"bam.eu01.nr-data.net",errorBeacon:"bam.eu01.nr-data.net",licenseKey:"NRJS-87cb4c448aca56623be",applicationID:"95776729",sa:1}
#   </script>
#   <style data-emotion="css-global 1trz8q9">
#    body{margin:0;font-family:ZooplaSans,Helvetica,Arial,sans-serif;box-sizing:border-box;line-height:1.15;-webkit-text-size-adjust:100%;}@font-face{font-family:'ZooplaSans';font-style:normal;font-weight:normal;font-display:swap;src:local('ZooplaSans'),local('ZooplaSans-Regular'),url('/fonts/ZooplaSans-Regular.woff2') format('woff2'),url('/fonts/ZooplaSans-Regular.woff') format('woff');}@font-face{font-family:'ZooplaSans';font-style:normal;font-weight:600;font-display:swap;src:local('ZooplaSans-SemiBold'),local('ZooplaSans-SemiBold'),url('/fonts/ZooplaSans-SemiBold.woff2') format('woff2'),url('/fonts/ZooplaSans-SemiBold.woff') format('woff');}*,*:before,*:after{box-sizing:inherit;}@media (prefers-reduced-motion: reduce){*{-webkit-animation:none!important;animation:none!important;transition-property:none!important;}}
#   </style>
#   <link as="font" crossorigin="anonymous" href="/fonts/ZooplaSans-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="/fonts/ZooplaSans-SemiBold.woff2" rel="preload" type="font/woff2"/>
#   <style data-emotion="css-global qbmvq2">
#    body .z-bui-component.z-bui-component .css-4oozw0-GlobalProvider{font-family:inherit;}
#   </style>
#   <link href="https://r.zoocdn.com" rel="preconnect"/>
#   <link href="https://lid.zoocdn.com" rel="preconnect"/>
#   <link href="https://gdpr.privacymanager.io" rel="preconnect"/>
#   <link href="https://gdpr-wrapper.privacymanager.io" rel="preconnect"/>
#   <script data-testid="inline-script">
#    window.dataLayer = window.dataLayer || [];
#   </script>
#   <script data-testid="inline-script">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-WNFR4ZC');
#   </script>
#   <script data-testid="inline-script">
#    (!function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t,e){var n=document.createElement("script");n.type="text/javascript";n.async=!0;n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(n,a);analytics._loadOptions=e};analytics.SNIPPET_VERSION="4.1.0";
#         analytics.load('kMettuB218zyYLIzUsT2ptxdGiEtWYT2');
#     }}())
#   </script>
#   <script async="" data-testid="baselayer-script" defer="" src="https://scripts.prod.zoopla.co.uk/baselayer.min.0.0.6.js">
#   </script>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    Houses for Sale in Liverpool - Buy Houses in Liverpool - Zoopla
#   </title>
#   <meta content="Find houses for sale in Liverpool with the UK's largest data-driven property portal. Browse detached, semi-detached and terraced properties to buy in Liverpool." name="description"/>
#   <link href="https://www.zoopla.co.uk/for-sale/houses/liverpool/" rel="canonical"/>
#   <link href="https://r.zoocdn.com/_next/static/images/apple-touch-icon-eef704c016bbaf62cf0574a23498d706.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://r.zoocdn.com/_next/static/images/favicon-32x32-4f2b054ba0516cd61a4e65816fed6e5f.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://r.zoocdn.com/_next/static/images/favicon-16x16-688e0971744b4769a92a8f2ee69b780d.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://r.zoocdn.com/_next/static/images/favicon-876be118935526ee522f78ec1d50080f.ico" rel="shortcut icon"/>
#   <link href="https://r.zoocdn.com/_next/static/other/site-d65fcd3db1233f186446d63ebfd0a1ea.webmanifest" rel="manifest"/>
#   <link color="#8046f1" href="https://r.zoocdn.com/_next/static/images/safari-pinned-tab-cfc4a2c98ae0696bcc7f4a44158c3d1b.svg" rel="mask-icon"/>
#   <meta content="https://r.zoocdn.com/_next/static/other/browserconfig-984c73468b8ad06e2fa0d6eb067e975d.xml" name="msapplication-config"/>
#   <meta content="#8046f1" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="zoopla" name="twitter:app:name:iphone"/>
#   <meta content="380932800" name="twitter:app:id:iphone"/>
#   <meta content="zoopla" name="twitter:app:name:googleplay"/>
#   <meta content="com.zoopla.activity" name="twitter:app:id:googleplay"/>
#   <meta content="zoopla:///for-sale/houses/liverpool/?beds_max=2&amp;price_max=300000&amp;view_type=list&amp;q=Liverpool%2C%20Merseyside&amp;results_sort=newest_listings&amp;search_source=home" name="twitter:app:url:iphone"/>
#   <meta content="android-app://com.zoopla.activity/zoopla/for-sale/houses/liverpool/?beds_max=2&amp;price_max=300000&amp;view_type=list&amp;q=Liverpool%2C%20Merseyside&amp;results_sort=newest_listings&amp;search_source=home" name="twitter:app:url:googleplay"/>
#   <meta content="100003926523449" property="fb:admins"/>
#   <meta content="19903963" property="twitter:account_id"/>
#   <script type="application/ld+json">
#    [
# 	{
# 		"alternateName": "Zoopla Property Search",
# 		"@context": "http://schema.org",
# 		"url": "https://www.zoopla.co.uk/",
# 		"name": "Zoopla",
# 		"@type": "WebSite"
# 	},
# 	{
# 		"@context": "http://schema.org",
# 		"breadcrumb": {
# 			"itemListElement": [
# 				{
# 					"position": 1,
# 					"item": {
# 						"name": "Zoopla",
# 						"@id": "https://www.zoopla.co.uk/"
# 					},
# 					"@type": "ListItem"
# 				},
# 				{
# 					"position": 2,
# 					"item": {
# 						"name": "For sale",
# 						"@id": "https://www.zoopla.co.uk/for-sale/"
# 					},
# 					"@type": "ListItem"
# 				},
# 				{
# 					"position": 3,
# 					"item": {
# 						"name": "Merseyside",
# 						"@id": "https://www.zoopla.co.uk/for-sale/houses/merseyside/"
# 					},
# 					"@type": "ListItem"
# 				},
# 				{
# 					"position": 4,
# 					"item": {
# 						"name": "Liverpool houses for sale",
# 						"@id": "https://www.zoopla.co.uk/for-sale/houses/liverpool/"
# 					},
# 					"@type": "ListItem"
# 				}
# 			],
# 			"@type": "BreadcrumbList"
# 		},
# 		"id": "https://www.zoopla.co.uk/for-sale/houses/liverpool/?beds_max=2&price_max=300000&view_type=list&q=Liverpool%2C%20Merseyside&results_sort=newest_listings&search_source=home",
# 		"@type": "WebPage"
# 	}
# ]
#   </script>
#   <link as="image" href="https://lid.zoocdn.com/645/430/74552884240a7af50a509c1278af1e172690ef0d.jpg" imagesizes="(min-width: 1280px) 800px, (min-width: 960px) 66vw, 100vw" rel="preload"/>
#   <meta content="25" name="next-head-count"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="https://r.zoocdn.com/_next/static/chunks/polyfills-5cd94c89d3acac5f.js">
#   </script>
#   <script data-nscript="beforeInteractive" defer="" src="https://scripts.prod.zoopla.co.uk/liveramp-consent-management-platform-1.4.0.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" data-testid="advert_adbridg_script" defer="" src="https://prod.adspsp.com/adb.3821450.min.js">
#   </script>
#   <script data-nscript="beforeInteractive" data-testid="advert_apstag_script" defer="" src="https://c.amazon-adsystem.com/aax2/apstag.js">
#   </script>
#   <script data-nscript="beforeInteractive" data-testid="advert_dfp_script" defer="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/webpack-0ad8a563fc1213be.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/framework-eeba1b405d308ec4.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/main-e9a8a8d06cfa9267.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/pages/_app-1ea6a8c2bc654133.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/0b32b42a-801767efe52d4c48.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/e238e344-1c9bfebbf76689a9.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/6249-db5714a7697ec4b0.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/3853-18879526300d50a7.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/911-4c995322ca5508e4.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/5620-e86a1b5cedeab33e.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/812-c2d061bde1730b68.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/970-0886fff4dd9f2484.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/7729-5bacb9355082cd57.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/5288-842a108054f29936.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/361-c02812743bdab900.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8168-dbbb46bee7338003.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/9011-2713dca11955dd26.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/5398-ddac8ff426a0f226.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/1313-dd360991f1b5ee9e.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8105-6fa37fcff459a39b.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/1782-b06a07fca4101c0d.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/7028-a682deaf4290f04c.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8906-2ba0dde997de96e9.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/806-11d09225f3d429cb.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8723-d64f126f969f8009.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/3499-a926a4966d7eda6d.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/9136-a760aa4e1bcf9582.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8817-71e7cbe16c938fbe.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/8149-c9f6feb8687c285e.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/2959-f40eb8a04fddf237.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/9342-c0e38044b8092c26.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/4778-c69ac5e2b10efc27.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/9833-b6de65d881d0d53a.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/224-fc7a5121e2ae4d3a.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/4281-d8423464ce26ec65.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/455-5f2353e891527852.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/4935-fe3eb941aac2cd9f.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/2895-bcae2209787d5630.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/chunks/pages/for-sale/%5B...search-path%5D-8c4ee45783d9c268.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/97c0372eprod/_buildManifest.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/97c0372eprod/_ssgManifest.js">
#   </script>
#   <script defer="" src="https://r.zoocdn.com/_next/static/97c0372eprod/_middlewareManifest.js">
#   </script>
#  </head>
#  <body>
#   <noscript>
#    <iframe data-testid="gtm-noscript" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WNFR4ZC" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <style data-emotion="css s85zyz-StyledHeader 88xogi-HeaderWrapper reat5a-HeaderContainer 1x8xshe-MainHeader 1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink zbjhxj-MaxWidthContainer 1onqvz2-LogoWrapper 1pkdy9s-StyledLink-Link-ResetLink f5u8oj-StyledLogo-ZooplaLogo-StyledZooplaLogo 6bb8vr-MobileActionsWrapper pdmv0p-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton-MenuButton 1jxjtaf-HamburgerWrapper hjiox8-HamburgerSpan mx98y1-Text gewbxo-MobileLinksWrapper r9fn4n-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton x4vu2o-StyledUserIcon 1gufgna-ProfileMenuWrapper 5mutq7-PrimaryList-ProfileWrapper 1lsk6fk-MyHomeLink wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon da2a1r-SavedLink 14j3ppk-SignInLink 1oi1pic-SignedInLink e3pd30-StyledLogoIcon 10dzl60-AccountMenuWrapper 3jk9sb-AccountWrapper gicaaf-MobileMenuWrapper y13qxj-StyledPrimaryNav 1vi0adm-PrimaryList-PrimaryListWrapper 17ocdwo-AccountMenu 14mzrsq-LinkWrapper xd6rax-AccordionIcon 3lib9c-SecondaryNavWrapper 1hvu47l-StyledMenuList ddh3vq-StyledLink-Link-ResetLink-StyledNavLink sy3kcm-Heading3 13my2sd-PrimaryList-ProfileWrapper-BottomMenuWrapper 1pse7sw-ButtonLink-Button-ResetButtonLink 1y8r5pq fbvwf6-StyledWrapper a2xa0g-Wrapper xzqxih-SearchInitationWrapper 17niatn-LocationWrapper dc8lqc-StyledInputBasic-StyledInput-InputAutoSuggestWithLabel 1jmcejq-Text-StyledSearchLabel wmd2qt-StyledDivider 7wpkvc-StyledDividerInner 8s9tc7-StyledMultiColumnDropdown-BedroomsWrapper l9db9j-Wrapper 1lzgjpi-StyledButton-MultiColumnDropdownWithLabel u7hzm6-Text-StyledMultiDropdownLabel tb0cnc-ButtonWrapper b5od6l-Text 11zqwlb-StyledDownArrowIcon 1k46ktq-StyledMultiColumnDropdown-PriceRangeMultiColumnDropdownWrapper 10gv344-StyledMultiColumnDropdown-PropertyTypeWrapper 1g1euun-StyledButtonWrapper y9pjer-Button-UpdateButton-StyledButton cmj44n-Text gy0btn-StyledIcon-Icon ekbr6h-StyledImg-Image 80v9ct-StyledMainFooter mu0br2-Heading2-StyledHiddenHeading2 jsgu20-StyledMoreWrapper 1ct0qn1-StyledList ngwpy6-StyledListItem ked27o-StyledBlock 10744x9-Heading4 1a2fmnh-StyledLink-Link-StyledButton 1jri6u0-StyledBlock 1lg4y9m-StyledBlock 8pz8kr-StyledList rdxr9z-ListItem 13rclhr-StyledSection eywbsn-Heading3-StyledHeading3 1etujbl-List 1xw1i0a-StyledLinkItem vf91cm-StyledLink-Link f6k7d-ListItem 1okau65-Heading3-StyledHiddenHeading3 ci02g7-StyledIconList 1a6or9z-ListItem 5ncccw-HiddenSpan rd820v-StyledSmallPrint 1wit0ml-List jszbjr-ListItem 19rc3w5-StyledLink-Link-StyledLink 9l7eo-StyledSmallPrintLayout 1bn2t6r-PageGalleryContent 6j8aie-Wrapper 1c0jkci-Container 17894u6-Viewport 1nvgks3-Slide 1i4h94a-SlideImageWrapper 1q97z4e-Tag 17lryky-SlideControlsContainer bmze52-ButtonLink-Button-ButtonLinkWithIcon 13lfztj-AdSlot 1gjbf5q-Button-ButtonWithIcon-DynamicNumberButton animation-1h1y9h1 1m4mec9-Text 1bqb4zy-StyledBreadcrumb-Breadcrumb acjyh-StyledBreadcrumbWrapper 14cknq9-StyledBreadcrumbItem kkr6vc-ButtonLink-Button-StyledLink 15hgk8r-StyledIconWrapper 4h8ll5-StickyQuickSearchBarDynamicShadow f8rrlc-StickyQuickSearchBarWrapper 6i81ti-StyledMobileQuickSearchBar 6gcrga-LocationWrapper 1540lqk-Wrapper ugvre1-MobileQuickSearchBarWrapper 13yibyu-StyledIcon-Icon-StyledIcon 59fowy-StyledLocationText p27re3-StyledRadiusText a7itt6-Divider 1yslzsk-Button-ButtonWithIcon-MobileFiltersButton zbr8n7-DesktopSubHeaderWrapper gvuram-SearchInputWrapper 1yxhane-StyledIconButton 15ejudo-StyledMultiColumnDropdown-SearchRadiusWrapper 1jpjel8-StyledDropdown-DropdownWithLabel 3f5a7t-Text-StyledDropdownLabel x5e7sb-StyledIcon 1wn73pq-SearchResultsWrapper o9zufp-MobileAlertPanelWrapper 8xoai0-Text-MobileText 1xcqjvt-Text-TabletText 12oyfjq-Divider aoaxu8-InnerWrapper 1ndyouf-Main 82dcw0-SearchResultsHeaderWrapper 1v38v3j-BreadcrumbsShowDesktopWrapper dbe7fg-Heading1 5imuct-Footer 1k7v433-FooterCell 1kx8akd-Text-SearchResultsTotalText mcov5v-Divider 4bhevr-ButtonLink-Button-ButtonLinkWithIcon-StyledMapIconLink qhlehm-Button-ButtonWithIcon-DesktopFiltersButton uke15d-Styl ...
#    @media only screen and (min-width: 960px){.css-s85zyz-StyledHeader{box-shadow:0px 0px 8px #3227440a,0px 0px 1px #32274452,0px 8px 8px -8px #32274429;}}.css-88xogi-HeaderWrapper{position:relative;z-index:998;font-size:medium;font-family:ZooplaSans,Helvetica,Arial,sans-serif,serif;font-variant:normal;font-weight:normal;letter-spacing:normal;text-align:left;visibility:visible;}.css-88xogi-HeaderWrapper *{background:none;border:none;margin:0;padding:0;position:static;-webkit-text-decoration:none;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:none;-webkit-transition:none;transition:none;font-size:inherit;font-variant:inherit;font-weight:inherit;letter-spacing:inherit;text-align:inherit;visibility:inherit;box-sizing:border-box;}@media (prefers-reduced-motion){.css-88xogi-HeaderWrapper *{-webkit-animation:none!important;animation:none!important;transition-property:none!important;}}.css-reat5a-HeaderContainer{position:relative;padding-top:4rem;background-color:#fff;}@media only screen and (min-width: 960px){.css-reat5a-HeaderContainer{padding-top:0;}}.css-1x8xshe-MainHeader{position:absolute;top:0;left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-flow:column nowrap;-webkit-flex-flow:column nowrap;-ms-flex-flow:column nowrap;flex-flow:column nowrap;cursor:auto;width:100%;max-width:100vw;overflow:hidden;box-shadow:0px 0px 8px rgba(50, 39, 68, 0.04),0px 0px 1px rgba(50, 39, 68, 0.32),0px 8px 8px -8px rgba(50, 39, 68, 0.16)!important;}.css-1x8xshe-MainHeader.is-resizing *{-webkit-animation:none!important;animation:none!important;-webkit-transition:none!important;transition:none!important;}@media only screen and (min-width: 960px){.css-1x8xshe-MainHeader{position:relative;top:auto;left:auto;-webkit-box-flex-flow:row wrap;-webkit-flex-flow:row wrap;-ms-flex-flow:row wrap;flex-flow:row wrap;overflow:visible;box-shadow:none!important;}}@media only screen and (min-width: 960px){.css-1x8xshe-MainHeader[data-universal-header-mobile-menu-open]{overflow-y:visible;}}.css-1x8xshe-MainHeader[data-universal-header-mobile-menu-open] .e1ydnppz4{width:100%;overflow-y:auto;height:100vh;-webkit-transition:height 0ms;transition:height 0ms;transition-delay:0ms;}.css-1x8xshe-MainHeader[data-universal-header-mobile-menu-open] .e1ydnppz4 .e1ydnppz9{position:relative;-webkit-transform:translate(0);-moz-transform:translate(0);-ms-transform:translate(0);transform:translate(0);}.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink{line-height:1.625;color:#322744;font-weight:600;display:inline;border-radius:4px;-webkit-text-decoration:underline;text-decoration:underline;text-decoration-color:#8046F1;text-decoration-thickness:1px;text-underline-position:under;position:absolute;background:#8046F1;font-size:1rem;border-radius:0.25rem;width:1px;height:1px;margin:-1px;-webkit-clip-path:inset(100%);clip-path:inset(100%);clip:rect(0 0 0 0);overflow:hidden;}.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:focus{outline:0;box-shadow:0 0 0 3px #FAC8F0;}.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:hover,.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:active{text-decoration-color:#662DBE;}.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:hover:not(:active){text-decoration-thickness:2px;}a.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink{color:#322744;font-weight:600;}a.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:visited{-webkit-text-decoration:none;text-decoration:none;color:#322744;}.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:active,.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:focus{top:0.5rem;left:1rem;display:block;width:auto;height:auto;margin:0;clip:auto;overflow:visible;padding:0.5rem;-webkit-clip-path:none;clip-path:none;z-index:3;}a.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink{color:#fff;}a.css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink:visited{color:#fff;-webkit-text-decoration:none;text-decorati ...
#   </style>
#   <style>
#    --sxs{--sxs:0 t-iPasBF}@media{:root,.t-iPasBF{--colors-purpleBright:#8046F1;--colors-purpleMid:#662DBE;--colors-purpleDark:#322744;--colors-white:#ffffff;--colors-purpleDarkTint1:#3227440a;--colors-purpleDarkTint2:#32274452;--colors-purpleDarkTint3:#32274429;--colors-purpleDarkTint4:#32274414;--colors-purpleDarkTint5:#3227443d;--colors-purpleDarkTint6:#322744CC;--colors-blue:#14325f;--colors-blueT3:#d7f6f5;--colors-blueT4:#E6FAFA;--colors-greenT3:#CDF0CD;--colors-greenT4:#EBFAE6;--colors-brownT3:#ffd2b9;--colors-brownT4:#ffe6dc;--colors-maroonT2:#FF91D7;--colors-maroonT3:#FAC8F0;--colors-maroonT4:#fae1f5;--colors-neutral1:#F7F6F5;--colors-neutral2:#E8E7E6;--colors-neutral3:#D1D0CF;--colors-neutral4:#949494;--colors-neutral5:#76767C;--colors-orangeT2:#FFC800;--colors-orangeT3:#FFF0A0;--colors-orangeT4:#fff8c8;--colors-error:#CC0000;--colors-errorContrast:#ff8080;--colors-prepopulated:var(--colors-blueT4);--colors-success:#007700;--colors-scrim:rgba(0, 0, 0, 0.3);--colors-focusRing:var(--colors-maroonT3);--colors-textBody:var(--colors-purpleDark);--colors-textTitle:var(--colors-purpleDark);--colors-textContrast:var(--colors-white);--colors-textPlaceholder:var(--colors-neutral5);--colors-textLinkDefault:var(--colors-purpleDark);--colors-textLinkHover:var(--colors-purpleDark);--colors-textLinkActive:var(--colors-purpleDark);--colors-textLinkVisited:var(--colors-blue);--colors-textLinkDisabled:var(--colors-neutral3);--colors-textLinkUnderlineDefault:var(--colors-purpleBright);--colors-textLinkUnderlineHover:var(--colors-purpleMid);--colors-textLinkUnderlineActive:var(--colors-purpleMid);--colors-graphicBackgroundDefault:var(--colors-white);--colors-graphicBackgroundContrast:var(--colors-purpleDark);--colors-graphicBackgroundAccentLight:var(--colors-neutral1);--colors-graphicBackgroundAccentDark:var(--colors-neutral2);--colors-graphicIconsLight:var(--colors-white);--colors-graphicIconsDark:var(--colors-purpleDark);--colors-graphicBuyingDefault:var(--colors-maroonT3);--colors-graphicBuyingLight:var(--colors-maroonT4);--colors-graphicSellingDefault:var(--colors-orangeT3);--colors-graphicSellingLight:var(--colors-orangeT4);--colors-graphicRentingDefault:var(--colors-blueT3);--colors-graphicRentingLight:var(--colors-blueT4);--colors-graphicImprovingDefault:var(--colors-brownT3);--colors-graphicImprovingLight:var(--colors-brownT4);--colors-graphicPriceDefault:var(--colors-greenT3);--colors-graphicPriceLight:var(--colors-greenT4);--colors-graphicDividerDefault:var(--colors-neutral3);--colors-graphicDividerLight:var(--colors-neutral2);--colors-buttonsPrimaryBackgroundDefault:var(--colors-purpleBright);--colors-buttonsPrimaryBackgroundHover:var(--colors-purpleMid);--colors-buttonsPrimaryBackgroundActive:var(--colors-purpleMid);--colors-buttonsPrimaryBackgroundDisabled:var(--colors-neutral2);--colors-buttonsPrimaryLabelDefault:var(--colors-white);--colors-buttonsPrimaryLabelDisabled:var(--colors-neutral3);--colors-buttonsSecondaryBackgroundDefault:var(--colors-white);--colors-buttonsSecondaryBackgroundHover:var(--colors-purpleDark);--colors-buttonsSecondaryBackgroundActive:var(--colors-purpleDark);--colors-buttonsSecondaryBackgroundDisabled:var(--colors-white);--colors-buttonsSecondaryBorderDefault:var(--colors-purpleDark);--colors-buttonsSecondaryBorderDisabled:var(--colors-neutral2);--colors-buttonsSecondaryLabelDefault:var(--colors-purpleDark);--colors-buttonsSecondaryLabelHover:var(--colors-white);--colors-buttonsSecondaryLabelActive:var(--colors-white);--colors-buttonsSecondaryLabelDisabled:var(--colors-neutral3);--colors-buttonsSecondaryIconActive:var(--colors-graphicIconsLight);--colors-buttonsSecondaryIconHover:var(--colors-graphicIconsLight);--colors-buttonsTertiaryBackgroundDefault:var(--colors-graphicBackgroundDefault);--colors-buttonsTertiaryLabelDefault:var(--colors-purpleDark);--colors-buttonsTertiaryLabelDisabled:var(--colors-neutral3);--colors-buttonsTertiaryBorderDefault:var(--colors-purpleBright);--colors-buttonsTertiary ...
#   </style>
#   <div id="__next">
#    <header class="css-s85zyz-StyledHeader e1ag9tec0">
#     <div class="css-88xogi-HeaderWrapper e7qedm11" id="main-header">
#      <div class="css-reat5a-HeaderContainer e1ydnppz2" data-is-logged-in="null" data-testid="header">
#       <div class="css-1x8xshe-MainHeader e1ydnppz3" data-universal-header="true">
#        <a class="e1ydnppz5 esdwd6d0 css-1qy14u1-StyledLink-Link-ResetLink-SkipToContentLink e33dvwd0" data-ajax="false" href="#main-content">
#         Skip to main content
#        </a>
#        <div class="css-zbjhxj-MaxWidthContainer e1ydnppz4" data-universal-header-container="true">
#         <div class="css-1onqvz2-LogoWrapper e1r69hd79">
#          <a aria-label="Zoopla" class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-logo" href="/">
#           <svg aria-hidden="true" class="e1r69hd70 css-f5u8oj-StyledLogo-ZooplaLogo-StyledZooplaLogo e1gdn2t70" color="white" data-testid="zoopla-logo" role="presentation" version="1.1" viewbox="0 0 110 20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#            <path d="M100.02 16.06c-3.27 0-5.82-2.28-5.82-6.06 0-3.68 2.41-6.09 5.82-6.09 3.6 0 5.98 2.63 5.98 6.12a5.76 5.76 0 01-5.98 6.03zM78.7 19.44h11.29v-3.57h-7.3V.56h-4v18.88zM68.29 12.5a4.18 4.18 0 01-4.35-4.37 4.22 4.22 0 014.35-4.37c2.55 0 4.42 1.72 4.42 4.37 0 2.66-1.87 4.37-4.42 4.37zm-8.34 6.95h4v-6.76a5.94 5.94 0 005.5 3.36c3.94 0 7.24-3.25 7.24-7.92S73.39.18 69.44.18c-2.41 0-4.4 1.2-5.5 3.36v-3h-4v18.9zm-11.78-3.32c-3.33 0-5.93-2.4-5.93-6.07 0-3.7 2.6-6.2 5.93-6.2 3.33 0 5.87 2.5 5.87 6.2 0 3.68-2.54 6.07-5.87 6.07zm.03 3.7c5.71 0 9.87-3.97 9.87-9.77 0-5.79-4.16-9.87-9.87-9.87-5.72 0-9.95 4.08-9.95 9.87 0 5.8 4.23 9.77 9.95 9.77zm-21.44-3.7c-3.32 0-5.9-2.4-5.9-6.07 0-3.7 2.58-6.2 5.9-6.2 3.33 0 5.9 2.5 5.9 6.2 0 3.68-2.57 6.07-5.9 6.07zm.03 3.7c5.71 0 9.87-3.97 9.87-9.77 0-5.79-4.15-9.87-9.87-9.87-5.71 0-9.95 4.08-9.95 9.87 0 5.8 4.24 9.77 9.95 9.77zM.48 19.44h15.5v-3.57H4.77c.1-2.81 2.12-3.56 4.4-4.34 3.14-1.07 6.76-2.44 6.76-9.55V.56H.53V4.1h11.16c-.1 2.65-2.07 3.35-4.3 4.1C4.24 9.28.49 10.64.49 18v1.44zm98.82.38a7.53 7.53 0 006.7-3.65v3.27h4V.56h-4V3.8A7.51 7.51 0 0099.3.18c-5 0-9.12 4.1-9.12 9.82 0 5.72 4.13 9.82 9.12 9.82z">
#            </path>
#           </svg>
#          </a>
#          <div class="css-6bb8vr-MobileActionsWrapper e1r69hd78">
#           <button aria-expanded="false" aria-label="Main menu" class="e1r69hd71 css-pdmv0p-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton-MenuButton eaqu47p1" data-ajax="false" data-testid="header-mobile-hamburger" data-track-action="click" data-track-category="navbar" data-track-label="open burger" data-universal-header-hamburger-button="true">
#            <div class="css-1jxjtaf-HamburgerWrapper e1r69hd74">
#             <span class="css-hjiox8-HamburgerSpan e1r69hd75">
#             </span>
#             <span class="css-hjiox8-HamburgerSpan e1r69hd75">
#             </span>
#             <span class="css-hjiox8-HamburgerSpan e1r69hd75">
#             </span>
#            </div>
#            <p class="css-mx98y1-Text eczcs4p0" data-id="open-button">
#             Menu
#            </p>
#            <p class="css-mx98y1-Text eczcs4p0" data-id="close-button">
#             Close
#            </p>
#           </button>
#           <div class="css-gewbxo-MobileLinksWrapper e1r69hd77">
#            <a class="e1r69hd72 css-r9fn4n-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton eaqu47p1" data-ajax="false" data-header-signin="/home-values/" data-myhome-button="true" data-testid="header-mobile-my-home" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;my home" href="/home-values/">
#             <svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#              <path clip-rule="evenodd" d="M7.765 10.067h4.22v9.512H19.8V6.799c0-.527-.278-1.016-.732-1.285L10.782.61A1.493 1.493 0 009.263.607L.935 5.515A1.493 1.493 0 00.2 6.8V19.58h7.565v-9.512zm-1.5 8.012v-8.012a1.5 1.5 0 011.5-1.5h4.22a1.5 1.5 0 011.5 1.5v8.012H18.3V6.803l-8.279-4.902-8.32 4.904V18.08h4.564z" fill-rule="evenodd">
#              </path>
#             </svg>
#             <p class="css-mx98y1-Text eczcs4p0">
#              My Home
#             </p>
#            </a>
#            <a class="e1r69hd72 css-r9fn4n-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton eaqu47p1" data-ajax="false" data-header-signin="/favourites/properties/" data-testid="header-mobile-saved" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;favourite properties" href="/favourites/properties/">
#             <svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#              <path clip-rule="evenodd" d="M.125 6.522c0-2.962 2.367-5.385 5.313-5.385 1.944 0 3.636 1.056 4.562 2.626.926-1.57 2.618-2.626 4.563-2.626 2.945 0 5.312 2.423 5.312 5.385 0 3.512-1.657 6.084-3.651 8.007-1.55 1.493-3.359 2.64-4.769 3.536-.38.24-.73.463-1.039.669a.75.75 0 01-.832 0c-.314-.21-.671-.436-1.058-.68-1.407-.891-3.208-2.031-4.75-3.514C1.782 12.62.126 10.048.126 6.522zm9.125 0c0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885 0 2.993 1.386 5.2 3.192 6.937 1.42 1.366 3.04 2.393 4.436 3.278.258.163.507.321.747.476.232-.15.474-.304.723-.462 1.4-.89 3.033-1.927 4.46-3.302 1.807-1.742 3.192-3.95 3.192-6.927 0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885a.75.75 0 01-1.5 0z" fill-rule="evenodd">
#              </path>
#             </svg>
#             <p class="css-mx98y1-Text eczcs4p0">
#              Saved
#             </p>
#            </a>
#            <a class="e1r69hd72 css-r9fn4n-ButtonLink-Button-ResetButtonLink-ActionButton-ActionWithLabelButton eaqu47p1" data-ajax="false" data-header-signin="/signin/?page_after_login={URL}&amp;return_url={URL}&amp;with_confirmation=true" data-is-logged-in="false" data-testid="header-mobile-sign-in" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;sign in" href="/signin/?page_after_login=%2Ffor-sale%2Fhouses%2Fliverpool%2F%3Fbeds_max%3D2%26price_max%3D300000%26view_type%3Dlist%26q%3DLiverpool%252C%2520Merseyside%26results_sort%3Dnewest_listings%26search_source%3Dhome&amp;return_url=%2Ffor-sale%2Fhouses%2Fliverpool%2F%3Fbeds_max%3D2%26price_max%3D300000%26view_type%3Dlist%26q%3DLiverpool%252C%2520Merseyside%26results_sort%3Dnewest_listings%26search_source%3Dhome&amp;with_confirmation=true">
#             <svg class="css-x4vu2o-StyledUserIcon e1r69hd76" fill="currentColor" height="20px" viewbox="0 0 16 16" width="20px" xmlns="http://www.w3.org/2000/svg">
#              <g clip-rule="evenodd" fill-rule="evenodd">
#               <path d="M8 7a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm0 1a2.5 2.5 0 100-5 2.5 2.5 0 000 5zM3 12.5A3.5 3.5 0 016.5 9h3a3.5 3.5 0 013.5 3.5V14h-1v-1.5A2.5 2.5 0 009.5 10h-3A2.5 2.5 0 004 12.5V14H3v-1.5z">
#               </path>
#               <path d="M8 1a7 7 0 100 14A7 7 0 008 1zM0 8a8 8 0 1116 0A8 8 0 010 8z">
#               </path>
#              </g>
#             </svg>
#             <p class="css-mx98y1-Text eczcs4p0">
#              Sign in
#             </p>
#            </a>
#           </div>
#          </div>
#          <div class="css-1gufgna-ProfileMenuWrapper e1kwm23x8">
#           <ul class="css-5mutq7-PrimaryList-ProfileWrapper e1kwm23x7" data-testid="header-profile">
#            <li class="css-1lsk6fk-MyHomeLink e1kwm23x0">
#             <a class="e1ydnppz6 css-wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon et03gpj0" data-ajax="false" data-myhome-button="true" data-testid="header-profilemenu-my-home" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;my home" href="/home-values/">
#              <div>
#               <svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M7.765 10.067h4.22v9.512H19.8V6.799c0-.527-.278-1.016-.732-1.285L10.782.61A1.493 1.493 0 009.263.607L.935 5.515A1.493 1.493 0 00.2 6.8V19.58h7.565v-9.512zm-1.5 8.012v-8.012a1.5 1.5 0 011.5-1.5h4.22a1.5 1.5 0 011.5 1.5v8.012H18.3V6.803l-8.279-4.902-8.32 4.904V18.08h4.564z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <p class="css-mx98y1-Text eczcs4p0">
#                My Home
#               </p>
#              </div>
#             </a>
#            </li>
#            <li class="css-da2a1r-SavedLink e1kwm23x1" data-is-logged-in="false">
#             <a class="e1ydnppz6 css-wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon et03gpj0" data-ajax="false" data-testid="header-profilemenu-favourites" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;favourite properties&gt;logged out" href="/signin/?page_after_login=/myaccount/favourites/&amp;return_url=/myaccount/favourites/">
#              <div>
#               <svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M.125 6.522c0-2.962 2.367-5.385 5.313-5.385 1.944 0 3.636 1.056 4.562 2.626.926-1.57 2.618-2.626 4.563-2.626 2.945 0 5.312 2.423 5.312 5.385 0 3.512-1.657 6.084-3.651 8.007-1.55 1.493-3.359 2.64-4.769 3.536-.38.24-.73.463-1.039.669a.75.75 0 01-.832 0c-.314-.21-.671-.436-1.058-.68-1.407-.891-3.208-2.031-4.75-3.514C1.782 12.62.126 10.048.126 6.522zm9.125 0c0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885 0 2.993 1.386 5.2 3.192 6.937 1.42 1.366 3.04 2.393 4.436 3.278.258.163.507.321.747.476.232-.15.474-.304.723-.462 1.4-.89 3.033-1.927 4.46-3.302 1.807-1.742 3.192-3.95 3.192-6.927 0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885a.75.75 0 01-1.5 0z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <p class="css-mx98y1-Text eczcs4p0">
#                Saved
#               </p>
#              </div>
#             </a>
#            </li>
#            <li class="css-da2a1r-SavedLink e1kwm23x1" data-is-logged-in="true">
#             <a class="e1ydnppz6 css-wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon et03gpj0" data-ajax="false" data-testid="header-profilemenu-favourites" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;favourite properties" href="/myaccount/favourites/">
#              <div>
#               <svg fill="currentColor" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M.125 6.522c0-2.962 2.367-5.385 5.313-5.385 1.944 0 3.636 1.056 4.562 2.626.926-1.57 2.618-2.626 4.563-2.626 2.945 0 5.312 2.423 5.312 5.385 0 3.512-1.657 6.084-3.651 8.007-1.55 1.493-3.359 2.64-4.769 3.536-.38.24-.73.463-1.039.669a.75.75 0 01-.832 0c-.314-.21-.671-.436-1.058-.68-1.407-.891-3.208-2.031-4.75-3.514C1.782 12.62.126 10.048.126 6.522zm9.125 0c0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885 0 2.993 1.386 5.2 3.192 6.937 1.42 1.366 3.04 2.393 4.436 3.278.258.163.507.321.747.476.232-.15.474-.304.723-.462 1.4-.89 3.033-1.927 4.46-3.302 1.807-1.742 3.192-3.95 3.192-6.927 0-2.156-1.718-3.885-3.813-3.885-2.094 0-3.812 1.729-3.812 3.885a.75.75 0 01-1.5 0z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <p class="css-mx98y1-Text eczcs4p0">
#                Saved
#               </p>
#              </div>
#             </a>
#            </li>
#            <li class="css-14j3ppk-SignInLink e1kwm23x2" data-is-logged-in="false">
#             <a class="e1ydnppz6 css-wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon et03gpj0" data-ajax="false" data-header-signin="/signin/?page_after_login={URL}&amp;return_url={URL}&amp;with_confirmation=true" data-testid="header-profile-sign-in" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;sign in" href="/signin/?page_after_login=%2Ffor-sale%2Fhouses%2Fliverpool%2F%3Fbeds_max%3D2%26price_max%3D300000%26view_type%3Dlist%26q%3DLiverpool%252C%2520Merseyside%26results_sort%3Dnewest_listings%26search_source%3Dhome&amp;return_url=%2Ffor-sale%2Fhouses%2Fliverpool%2F%3Fbeds_max%3D2%26price_max%3D300000%26view_type%3Dlist%26q%3DLiverpool%252C%2520Merseyside%26results_sort%3Dnewest_listings%26search_source%3Dhome&amp;with_confirmation=true">
#              <div>
#               <svg fill="currentColor" height="20" viewbox="0 0 16 16" width="20" xmlns="http://www.w3.org/2000/svg">
#                <g clip-rule="evenodd" fill-rule="evenodd">
#                 <path d="M8 7a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm0 1a2.5 2.5 0 100-5 2.5 2.5 0 000 5zM3 12.5A3.5 3.5 0 016.5 9h3a3.5 3.5 0 013.5 3.5V14h-1v-1.5A2.5 2.5 0 009.5 10h-3A2.5 2.5 0 004 12.5V14H3v-1.5z">
#                 </path>
#                 <path d="M8 1a7 7 0 100 14A7 7 0 008 1zM0 8a8 8 0 1116 0A8 8 0 010 8z">
#                 </path>
#                </g>
#               </svg>
#               <p class="css-mx98y1-Text eczcs4p0">
#                Sign in
#               </p>
#              </div>
#             </a>
#            </li>
#            <li class="css-1oi1pic-SignedInLink e1kwm23x4" data-is-logged-in="true">
#             <a class="e1ydnppz6 css-wkuucx-ButtonLink-Button-ButtonLinkWithIcon-ResetButtonLinkWithIcon et03gpj0" data-ajax="false" data-testid="header-profile-account" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account" href="/myaccount/">
#              <div>
#               <div class="css-e3pd30-StyledLogoIcon e1kwm23x3">
#               </div>
#               <p class="css-mx98y1-Text eczcs4p0">
#                My Zoopla
#               </p>
#              </div>
#             </a>
#             <div class="css-10dzl60-AccountMenuWrapper e1kwm23x5">
#              <ul class="css-3jk9sb-AccountWrapper e1e39srw0">
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-saved-listing" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;favourite properties" href="/favourites/properties/">
#                 Saved listings
#                </a>
#               </li>
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-tracked-properties" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;tracked properties" href="/favourites/tracked-properties/">
#                 Tracked properties
#                </a>
#               </li>
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-alerts-searches" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;alerts &amp; searches" href="/myaccount/alerts-searches/">
#                 Alerts and searches
#                </a>
#               </li>
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-email-preferences" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;email preferences" href="/myaccount/account/preferences/">
#                 Email preferences
#                </a>
#               </li>
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-account" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;manage account" href="/myaccount/">
#                 More account settings
#                </a>
#               </li>
#               <li>
#                <a class="e1ydnppz8 esdwd6d0 css-1pkdy9s-StyledLink-Link-ResetLink e33dvwd0" data-ajax="false" data-testid="header-profilemenu-sign-out" data-track-action="clickthrough" data-track-category="User Account" data-track-label="user account&gt;sign out" href="/?signout=1">
#                 Sign out
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
# ...
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <g clip-path="url(#clip0)">
#            <path d="M32 16c0-8.837-7.162-16-16-16C7.163 0 0 7.163 0 16c0 7.988 5.85 14.606 13.5 15.806v-11.18H9.438V16H13.5v-3.525c0-4.01 2.388-6.225 6.044-6.225 1.75 0 3.581.313 3.581.313V10.5h-2.019c-1.987 0-2.606 1.234-2.606 2.5v3h4.438l-.71 4.625H18.5v11.181C26.15 30.606 32 23.988 32 16z">
#            </path>
#           </g>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla Facebook page
#          </span>
#         </a>
#        </li>
#        <li class="css-1a6or9z-ListItem ecup3kz1">
#         <a class="esdwd6d0 css-vf91cm-StyledLink-Link e33dvwd0" data-testid="social-link-twitter" data-track-action="clickout" data-track-category="footer" data-track-label="twitter" href="https://twitter.com/zoopla" rel="noopener noreferrer" target="_blank" title="This link opens in a new window">
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <path clip-rule="evenodd" d="M10.063 28c12.076 0 18.68-9.234 18.68-17.242 0-.262 0-.524-.018-.784A12.84 12.84 0 0032 6.838a13.97 13.97 0 01-3.77.953c1.37-.757 2.395-1.948 2.886-3.352a13.843 13.843 0 01-4.17 1.471c-2.486-2.44-6.645-2.558-9.289-.263-1.705 1.48-2.428 3.686-1.899 5.79-5.279-.244-10.197-2.546-13.53-6.331-1.743 2.769-.853 6.31 2.032 8.09a6.936 6.936 0 01-2.98-.76v.077c0 2.885 2.204 5.37 5.267 5.94a7.086 7.086 0 01-2.964.105c.86 2.468 3.325 4.16 6.133 4.208-2.324 1.687-5.196 2.602-8.153 2.6-.522-.002-1.044-.03-1.563-.088C3.002 27.056 6.496 28 10.063 27.995" fill-rule="evenodd">
#           </path>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla Twitter profilee
#          </span>
#         </a>
#        </li>
#        <li class="css-1a6or9z-ListItem ecup3kz1">
#         <a class="esdwd6d0 css-vf91cm-StyledLink-Link e33dvwd0" data-testid="social-link-linkedin" data-track-action="clickout" data-track-category="footer" data-track-label="linkedin" href="https://www.linkedin.com/company/zoopla/about" rel="noopener noreferrer" target="_blank" title="This link opens in a new window">
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <g clip-path="url(#clip0)">
#            <path clip-rule="evenodd" d="M27.266 27.268h-4.742v-7.426c0-1.77-.035-4.05-2.467-4.05-2.47 0-2.847 1.93-2.847 3.922v7.554h-4.74v-15.27h4.55v2.086h.065c.633-1.201 2.182-2.467 4.491-2.467 4.802 0 5.69 3.162 5.69 7.274v8.377zM7.12 9.909a2.751 2.751 0 110-5.504 2.753 2.753 0 010 5.504zM4.742 27.267h4.75v-15.27h-4.75v15.27zM29.63 0H2.36C1.059 0 0 1.033 0 2.306v27.386C0 30.966 1.059 32 2.36 32h27.27c1.304 0 2.37-1.034 2.37-2.308V2.306C32 1.033 30.934 0 29.63 0z" fill-rule="evenodd">
#            </path>
#           </g>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla LinkedIn profile
#          </span>
#         </a>
#        </li>
#        <li class="css-1a6or9z-ListItem ecup3kz1">
#         <a class="esdwd6d0 css-vf91cm-StyledLink-Link e33dvwd0" data-testid="social-link-instagram" data-track-action="clickout" data-track-category="footer" data-track-label="instagram" href="https://www.instagram.com/zoopla" rel="noopener noreferrer" target="_blank" title="This link opens in a new window">
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <g>
#            <path clip-rule="evenodd" d="M16 7.784a8.216 8.216 0 100 16.433 8.216 8.216 0 000-16.433zm0 13.55a5.334 5.334 0 110-10.668 5.334 5.334 0 010 10.667z" fill-rule="evenodd">
#            </path>
#            <path d="M26.461 7.459a1.92 1.92 0 11-3.84 0 1.92 1.92 0 013.84 0z">
#            </path>
#            <path clip-rule="evenodd" d="M16 0c-4.345 0-4.89.019-6.597.096-2.6.119-4.884.756-6.718 2.59C.852 4.518.215 6.802.096 9.402.019 11.109 0 11.655 0 16c0 4.345.019 4.89.096 6.597.119 2.6.756 4.884 2.59 6.718 1.833 1.833 4.117 2.47 6.717 2.589 1.706.077 2.252.096 6.597.096 4.345 0 4.89-.019 6.597-.096 2.6-.119 4.884-.756 6.718-2.59 1.833-1.833 2.47-4.117 2.589-6.717.077-1.706.096-2.252.096-6.597 0-4.345-.019-4.89-.096-6.597-.119-2.6-.756-4.884-2.59-6.718C27.482.852 25.198.215 22.598.096 20.891.019 20.345 0 16 0zm0 2.883c4.272 0 4.779.016 6.465.093 1.822.083 3.511.448 4.811 1.748 1.3 1.3 1.665 2.99 1.748 4.81.077 1.687.093 2.194.093 6.466s-.016 4.779-.093 6.465c-.083 1.822-.448 3.511-1.748 4.811-1.3 1.3-2.99 1.665-4.81 1.748-1.687.077-2.194.093-6.466.093s-4.779-.016-6.465-.093c-1.822-.083-3.511-.448-4.811-1.748-1.3-1.3-1.665-2.99-1.748-4.81-.077-1.687-.093-2.194-.093-6.466s.016-4.779.093-6.465c.083-1.822.448-3.511 1.748-4.811 1.3-1.3 2.99-1.665 4.81-1.748 1.687-.077 2.194-.093 6.466-.093z" fill-rule="evenodd">
#            </path>
#           </g>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla Instagram feed
#          </span>
#         </a>
#        </li>
#        <li class="css-1a6or9z-ListItem ecup3kz1">
#         <a class="esdwd6d0 css-vf91cm-StyledLink-Link e33dvwd0" data-testid="social-link-youtube" data-track-action="clickout" data-track-category="footer" data-track-label="youtube" href="https://www.youtube.com/user/ZooplaUK" rel="noopener noreferrer" target="_blank" title="This link opens in a new window">
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <g clip-path="url(#clip0)">
#            <path clip-rule="evenodd" d="M12.727 20.727v-9.455L21.091 16l-8.364 4.727zm18.604-12.43a4.008 4.008 0 00-2.83-2.829C26.008 4.8 16 4.8 16 4.8s-10.007 0-12.502.668a4.008 4.008 0 00-2.83 2.83C0 10.793 0 16 0 16s0 5.206.669 7.703a4.008 4.008 0 002.829 2.829C5.993 27.2 16 27.2 16 27.2s10.007 0 12.502-.668a4.008 4.008 0 002.829-2.83C32 21.207 32 16 32 16s0-5.206-.67-7.703z" fill-rule="evenodd">
#            </path>
#           </g>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla YouTube channel
#          </span>
#         </a>
#        </li>
#        <li class="css-1a6or9z-ListItem ecup3kz1">
#         <a class="esdwd6d0 css-vf91cm-StyledLink-Link e33dvwd0" data-testid="social-link-pinterest" data-track-action="clickout" data-track-category="footer" data-track-label="pinterest" href="https://uk.pinterest.com/zoopla" rel="noopener noreferrer" target="_blank" title="This link opens in a new window">
#          <svg fill="#322744" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#           <path clip-rule="evenodd" d="M16 0C7.163 0 0 7.163 0 16c0 6.778 4.217 12.573 10.17 14.904-.14-1.266-.267-3.213.055-4.595.29-1.248 1.876-7.953 1.876-7.953s-.479-.958-.479-2.375c0-2.225 1.29-3.886 2.895-3.886 1.365 0 2.025 1.025 2.025 2.254 0 1.373-.874 3.425-1.325 5.327-.377 1.593.798 2.892 2.369 2.892 2.844 0 5.03-2.999 5.03-7.327 0-3.831-2.753-6.51-6.684-6.51-4.552 0-7.224 3.415-7.224 6.944 0 1.375.53 2.85 1.19 3.651.131.159.15.297.111.46-.121.505-.391 1.591-.444 1.814-.07.292-.232.354-.535.214-1.998-.93-3.248-3.852-3.248-6.199 0-5.047 3.667-9.682 10.572-9.682 5.55 0 9.864 3.955 9.864 9.24 0 5.515-3.477 9.953-8.303 9.953-1.621 0-3.145-.843-3.667-1.838 0 0-.802 3.055-.997 3.804-.361 1.39-1.336 3.132-1.988 4.194C12.76 31.75 14.35 32 16 32c8.837 0 16-7.163 16-16S24.837 0 16 0" fill-rule="evenodd">
#           </path>
#          </svg>
#          <span class="css-5ncccw-HiddenSpan ecup3kz0">
#           Zoopla Pinterest board
#          </span>
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="css-f6k7d-ListItem e1jgslov0">
#       <div class="css-rd820v-StyledSmallPrint e1fkq0jk4">
#        <h3 class="css-1okau65-Heading3-StyledHiddenHeading3 e1jgslov2">
#         Legal and corporate information
#        </h3>
#        <ul class="css-1wit0ml-List e1fkq0jk2">
#         <li class="css-jszbjr-ListItem e1fkq0jk1">
#          <a class="e1fkq0jk0 css-19rc3w5-StyledLink-Link-StyledLink e33dvwd0" data-track-action="clickthrough" data-track-category="footer" data-track-label="zoopla estimates" href="/property/estimate/about/">
#           Zoopla estimates
#          </a>
#         </li>
#         <li class="css-jszbjr-ListItem e1fkq0jk1">
#          <a class="e1fkq0jk0 css-19rc3w5-StyledLink-Link-StyledLink e33dvwd0" data-track-action="clickthrough" data-track-category="footer" data-track-label="street index" href="/property/streets/">
#           Street index
#          </a>
#         </li>
#         <li class="css-jszbjr-ListItem e1fkq0jk1">
#          <a class="e1fkq0jk0 css-19rc3w5-StyledLink-Link-StyledLink e33dvwd0" data-track-action="clickthrough" data-track-category="footer" data-track-label="popular areas" href="/sitemap/popular-areas/">
#           Popular areas
#          </a>
#         </li>
#         <li class="css-jszbjr-ListItem e1fkq0jk1">
#          <p>
#           ©
#           <!-- -->
#           2022
#           <!-- -->
#           Zoopla Limited. All rights reserved.
#          </p>
#         </li>
#        </ul>
#        <p class="css-mx98y1-Text eczcs4p0">
#         Sold house prices provided by Land Registry/Registers of Scotland. © Crown copyright
#         <!-- -->
#         2022
#         <!-- -->
#         .
#        </p>
#        <div class="css-9l7eo-StyledSmallPrintLayout e1fkq0jk3">
#         <div>
#          <p class="css-mx98y1-Text eczcs4p0">
#           Our website is completely free for you to use but we may receive a commission from some of the companies we link to on the site.
#          </p>
#          <p class="css-mx98y1-Text eczcs4p0">
#           *Zoopla Limited is an appointed representative of Uswitch Limited which is authorised and regulated by the Financial Conduct Authority (FRN 312850) to provide this mortgage comparison service.
#          </p>
#         </div>
#         <div>
#          <p class="css-mx98y1-Text eczcs4p0">
#           **Uswitch Limited is authorised and regulated by the Financial Conduct Authority (FCA) under firm reference number 312850.
#          </p>
#         </div>
#        </div>
#       </div>
#      </li>
#     </ul>
#     <script>
#      (function () {
#     function init() {
#       const cookiePolicyLink = document.getElementById('cookie_policy');
#
#       if (!cookiePolicyLink) {
#         return;
#       }
#
#       cookiePolicyLink.addEventListener('click', function (event) {
#         if (window.__tcfapi) {
#           event.preventDefault();
#           const LiveRampVersion = 2;
#
#           window.__tcfapi('showConsentManager', LiveRampVersion);
#         }
#       });
#     }
#
#     window.addEventListener('DOMContentLoaded', init);
#   })()
#     </script>
#    </footer>
#   </div>
#   <script data-testid="inline-script">
#    "undefined"!=typeof ResizeObserver&&"undefined"!=typeof globalThis||(window.onload=function(){var e=document.createElement("a");e.style.cssText="color:#322744",e.href="https://help.zoopla.co.uk/hc/en-gb/articles/4412635888529-Unsupported-browser",void 0!==e.textContent?e.textContent="updating your browser.":e.innerText="updating your browser.";var t=document.createElement("div");t.id="browser-msg",t.style.cssText="position:fixed !important;position:absolute;width:100%;top:0;z-index:999;background:#fff0a0;padding:12px 16px;text-align:center;",void 0!==e.textContent?t.textContent="Your web browser is out of date. Get the best Zoopla experience by ":t.innerText="Your web browser is out of date. Get the best Zoopla experience by ",t.appendChild(e),document.body.appendChild(t);var o=document.getElementById("main-header");o&&setTimeout(function(){document.getElementById("browser-msg");var e=t.offsetHeight;o.style.cssText="margin-top:"+e+"px;"},100)});
#   </script>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"initialProps":{"analyticsTaxonomy":{"__typename":"AnalyticsTaxonomy","url":"/for-sale/houses/liverpool/?beds_max=2\u0026price_max=300000\u0026view_type=list\u0026q=Liverpool%2C%20Merseyside\u0026results_sort=newest_listings\u0026search_source=home","areaName":"Liverpool","activity":"listing_search","brand":"zoopla","countryCode":"gb","countyAreaName":"Merseyside","currencyCode":"GBP","listingsCategory":"residential","outcode":"L25","outcodes":["L25","L11","L19","L33","L7","L20","L23","L31","L21","L28","L32","L13","L8","L14","L5","L18","L36"],"page":"/for-sale/results/","postalArea":"L","radius":0,"radiusAutoexpansion":null,"regionName":"North West England","resultsSort":"newest_listings","searchGuid":"9D739370701411EC8D8F9D01D1874D44","searchIdentifier":"5bffe0311e55e3d157e632987a2916a5","section":"for-sale","searchLocation":"Liverpool, Merseyside","viewType":"list","searchResultsCount":179,"expandedResultsCount":0,"totalResults":179,"emailAllFormShown":true,"emailAllTotalAgents":29,"bedsMax":"2","bedsMin":null,"priceMax":"300000","priceMin":"","location":null,"propertyType":"houses"},"initialState":{"favourites":{"listings":[]},"dfpAdTargeting":{"typename":"AdTargeting","activity":"listing_search","area_name":"Liverpool","beds_max":"2","beds_min":"","brand":"zoopla","brand_primary":"zoopla","county_area_name":"Merseyside","country_code":"gb","currency_code":"GBP","listings_category":"residential","outcode":"L25","outcodes":["L25","L11","L19","L33","L7","L20","L23","L31","L21","L28","L32","L13","L8","L14","L5","L18","L36"],"page":"/for-sale/results/","postal_area":"L","price_max":"300000","price_min":"","property_type":"houses","region_name":"North West England","results_sort":"newest_listings","search_location":"Liverpool, Merseyside","search_results_count":"179","section":"for-sale","total_results":"179","url":"/for-sale/houses/liverpool/?beds_max=2\u0026price_max=300000\u0026view_type=list\u0026q=Liverpool%2C%20Merseyside\u0026results_sort=newest_listings\u0026search_source=home","view_type":"list"},"seoAccordions":[{"__typename":"SeoAccordions","category":"residential","expanded":true,"geo":"Liverpool","name":"currentlyAvailable","propertyType":"houses","section":"for-sale","transactionType":"sale","rows":[{"__typename":"Row","links":[{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"houses","section":"for-sale","transactionType":"sale","uri":"/for-sale/houses/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"houses","section":"for-sale","transactionType":"sale","uri":"/for-sale/houses/2-bedrooms/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"houses","section":"for-sale","transactionType":"sale","uri":"/for-sale/houses/3-bedrooms/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"houses","section":"for-sale","transactionType":"sale","uri":"/for-sale/houses/4-bedrooms/liverpool/"}]},{"__typename":"Row","links":[{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"flats","section":"for-sale","transactionType":"sale","uri":"/for-sale/flats/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"flats","section":"for-sale","transactionType":"sale","uri":"/for-sale/flats/1-bedroom/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"flats","section":"for-sale","transactionType":"sale","uri":"/for-sale/flats/2-bedrooms/liverpool/"}]},{"__typename":"Row","links":[{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"property","section":"for-sale","transactionType":"sale","uri":"/for-sale/property/liverpool/"},{"__typename":"Link","category":"residential","geo":"Liverpool","propertyType":"property","section":"for-sale","transactionType":"sale","uri":"/for-sale/property/1-bedroom/liverpool/"},{"__typename":"Link","categ ...
#   </script>
#  </body>
# </html>

# %% [markdown]
# Scrape the data from the web

# %%
property_elements = results.find_all("div", class_="earci3d1 css-1af14jc-Wrapper-ListingCard-StyledListingCard e2uk8e11")

# %%
for properties in property_elements:
    price = properties.find("p",class_="css-1o565rw-Text eczcs4p0")
    bedrooms = properties.find("p",class_="css-r8a2xt-Text eczcs4p0")
    description = properties.find("h2",class_="css-vthwmi-Heading2-StyledAddress e2uk8e16")
    address = properties.find("p",class_="css-nwapgq-Text eczcs4p0")
    print(price.text.strip())
    print(bedrooms.text.strip())
    print(description.text.strip())
    print(address.text.strip())
    print()

#.text returns only the text content of the HTML elements that the object contains
#.strip() removes the unnecessary whitespace
# Out:
# £145,000
# 2
# 2 bed terraced house for sale
# Pitt Place, Woolton, Liverpool L25
#
# £140,000
# 2
# 2 bed terraced house for sale
# Pitt Place, Woolton, Liverpool L25
#
# £140,000
# 2
# 2 bed terraced house for sale
# Pitt Place, Woolton, Liverpool L25
#
# £90,000
# 2
# 2 bed terraced house for sale
# Sceptre Road, Croxteth, Liverpool L11
#
# £140,000
# 2
# 2 bed terraced house for sale
# Ebrington Street, Garston, Liverpool L19
#
# £110,000
# 2
# 2 bed terraced house for sale
# Aspen Close, Liverpool L33
#
# £140,000
# 2
# 2 bed terraced house for sale
# Belper Street, Liverpool L19
#
# £95,000
# 2
# 2 bed terraced house for sale
# Spofforth Road, Liverpool, Merseyside L7
#
# £170,000
# 2
# 2 bed semi-detached house for sale
# Park Lane, Bootle, Merseyside L20
#
# £290,000
# 2
# 2 bed bungalow for sale
# Windmill Avenue, Crosby, Liverpool L23
#
# £160,000
# 2
# 2 bed semi-detached bungalow for sale
# Park Lane, Maghull, Liverpool, Merseyside L31
#
# £70,000
# 2
# 2 bed terraced house for sale
# Verdi Terrace, Seaforth, Liverpool L21
#
# £100,000
# 2
# 2 bed terraced house for sale
# Hornby Road, Bootle L20
#
# £90,000
# 2
# 2 bed terraced house for sale
# Brandearth Hey, Liverpool, Merseyside L28
#
# £99,950
# 2
# 2 bed terraced house for sale
# Cawthorne Close, Southdene L32
#
# £90,000
# 2
# 2 bed terraced house for sale
# Sapphire Street, Wavertree, Liverpool L13
#
# £99,950
# 2
# 2 bed end terrace house for sale
# Morston Avenue, Southdene L32
#
# £85,000
# 2
# 2 bed end terrace house for sale
# Colwell Close, Liverpool L14
#
# £145,000
# 2
# 2 bed bungalow for sale
# Hartsbourne Avenue, Liverpool L25
#
# £70,000
# 2
# 2 bed terraced house for sale
# Daisy Street, Kirkdale, Liverpool L5

# %% [markdown]
# >Instances where only the values for a specific column are required is shown below

# %% [markdown]
# ### Specific fields

# %% [markdown]
# #### Price

# %%
for properties in property_elements:
    price = properties.find("p",class_="css-1o565rw-Text eczcs4p0")
    print(price.text.strip())
# Out:
# £145,000
# £140,000
# £140,000
# £90,000
# £140,000
# £110,000
# £140,000
# £95,000
# £170,000
# £290,000
# £160,000
# £70,000
# £100,000
# £90,000
# £99,950
# £90,000
# £99,950
# £85,000
# £145,000
# £70,000

# %%
for properties in property_elements:
    bedrooms = properties.find("p",class_="css-r8a2xt-Text eczcs4p0")
    print(bedrooms.text.strip())
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
for properties in property_elements:
    description = properties.find("h2",class_="css-vthwmi-Heading2-StyledAddress e2uk8e16")
    print(description.text.strip())
# Out:
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed semi-detached house for sale
# 2 bed bungalow for sale
# 2 bed semi-detached bungalow for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed terraced house for sale
# 2 bed end terrace house for sale
# 2 bed end terrace house for sale
# 2 bed bungalow for sale
# 2 bed terraced house for sale

# %%
for properties in property_elements:
    address = properties.find("p",class_="css-nwapgq-Text eczcs4p0")
    print(address.text.strip())
# Out:
# Pitt Place, Woolton, Liverpool L25
# Pitt Place, Woolton, Liverpool L25
# Pitt Place, Woolton, Liverpool L25
# Sceptre Road, Croxteth, Liverpool L11
# Ebrington Street, Garston, Liverpool L19
# Aspen Close, Liverpool L33
# Belper Street, Liverpool L19
# Spofforth Road, Liverpool, Merseyside L7
# Park Lane, Bootle, Merseyside L20
# Windmill Avenue, Crosby, Liverpool L23
# Park Lane, Maghull, Liverpool, Merseyside L31
# Verdi Terrace, Seaforth, Liverpool L21
# Hornby Road, Bootle L20
# Brandearth Hey, Liverpool, Merseyside L28
# Cawthorne Close, Southdene L32
# Sapphire Street, Wavertree, Liverpool L13
# Morston Avenue, Southdene L32
# Colwell Close, Liverpool L14
# Hartsbourne Avenue, Liverpool L25
# Daisy Street, Kirkdale, Liverpool L5
